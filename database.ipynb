# %% [markdown]
# ## base de dados temperatura de Brasilia

# %%
# !pip install wget
import pandas as pd
import wget

url = "https://raw.githubusercontent.com/Feguto/temperature_base/main/database.csv.csv"

wget.download(url, out='database.csv.csv')
df = pd.read_csv('database.csv.csv', sep=';', encoding='ISO-8859-1')
df.head()
# Out:
# ...
#   M̻s,Dia,Pressao Atmosferica
# 0                     1,1,89.7
# 1                     1,1,89.6
# 2                     1,1,89.5
# 3                     1,1,89.6
# 4                     1,1,89.5
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('M̻s,Dia,Pressao Atmosferica').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
# ...
